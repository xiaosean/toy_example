# %%
from typing import Optional

import uvicorn
from fastapi import FastAPI
from fastapi.encoders import jsonable_encoder
from fastapi.responses import JSONResponse
from pyquery import PyQuery as pq
from requests_html import HTMLSession


app = FastAPI()
user_dict = {}

@app.get("/test")
def abc():
# check 127.0.0.1:5000/test
    return "In test page"


@app.get("/")
def hello():
# check 127.0.0.1:5000
    return "Hello World!"


@app.get("/ani_gamer")
def ani_gamer_get_list():
    # 獲取請求對象 
    session = HTMLSession() 
    # 往巴哈姆特動畫瘋發送get請求 
    ani_gamer = session.get('https://ani.gamer.com.tw/')
    print(f"ani_gamer.text = {ani_gamer.text}")
    # 利用 Pyquery 文本解析
    page = pq(ani_gamer.text) 
    anime_list = []
    # 萃取出本季的動畫列表並回傳
    for anime_name in page.find(".anime-name_for-marquee"):
        anime_list.append(pq(anime_name).text())
    print(f"anime_list = {anime_list}")
    return " ".join(anime_list)

@app.get("/ani_gamer_json")
def ani_gamer_get_json():
    # 獲取請求對象 
    session = HTMLSession() 
    # 往巴哈姆特動畫瘋發送get請求 
    ani_gamer = session.get('https://ani.gamer.com.tw/')
    print(f"ani_gamer.text = {ani_gamer.text}")
    # 利用 Pyquery 文本解析
    page = pq(ani_gamer.text) 
    anime_dict = {}
    # 萃取出本季的動畫列表並回傳
    for block in page.find(".anime-block"):
        anime_name = pq(block).find(".anime-name_for-marquee").text()
        href =  "https://ani.gamer.com.tw/" + pq(block).find(".anime-card-block").attr("href")
        anime_episode = pq(block).find(".anime-episode").text()
        # print(f"======={anime_name}========")
        # print(f"最新連載 = {anime_episode}")
        # print(f"連結 = {href}")
        # print()
        anime_dict[f"{anime_name}_{anime_episode}"] = href
    print(f"anime_dict = {anime_dict}")
    return anime_dict
#
#     return jsonify(anime_dict)
    

if __name__ == "__main__":
    # app.run()
    uvicorn.run("main:app", host="0.0.0.0", port=8000, reload=True, debug=True)
# Out:
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2283] using statreload

# %%
from pyquery import PyQuery as pq
from requests_html import HTMLSession

# %%
# 獲取請求對象 
session = HTMLSession() 
# 往巴哈姆特動畫瘋發送get請求 
ani_gamer = session.get('https://ani.gamer.com.tw/')
# print(f"ani_gamer.text = {ani_gamer.text}")

str(ani_gamer.text).find("day-list today-list")
# Out:
# 175211

# %%
page = pq(ani_gamer.text) 
page(".day-title ")
# Out:
# [<h3.day-title>, <h3.day-title>, <h3.day-title>, <h3.day-title>, <h3.day-title>, <h3.day-title>, <h3.day-title>]

# %%
# 利用 Pyquery 文本解析
page = pq(ani_gamer.text) 
anime_dict = {}
# 萃取出本季的動畫列表並回傳
for block in page.find(".day-list"):
    day_of_week = pq(block).find(".day-title").text()
    print(f"day_of_week = {day_of_week}")
#     Create dictionary of day of week
#   {
#     週一： {}
#     週二： {}
#     週三： {}
#     ......
#     週日： {}
#     }
    anime_dict[f"{day_of_week}"] = {}
    for anime in page(block).find(".text-anime-info"):
        anime_name = pq(anime).find(".text-anime-name").text()
        href =  "https://ani.gamer.com.tw/" + pq(anime).attr("href")
        anime_episode = pq(anime).find(".text-anime-number").text()
        print(f"======={anime_name}========")
        print(f"最新連載 = {anime_episode}")
        print(f"連結 = {href}")
        print()
#         anime_dict[f"{anime_name}_{anime_episode}"] = href
        anime_dict[f"{day_of_week}"][f"{anime_name}_{anime_episode}"] = href
# print(f"anime_dict = {anime_dict}")
# return anime_dict
# return jsonify(anime_dict)
print(anime_dict)
# Out:
# day_of_week = 週一
# =======再見了，我的克拉默========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23142
#
# =======王者天下 第三季========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23145
#
# =======刮掉鬍子的我與撿到的女高中生========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23151
#
# day_of_week = 週二
# =======給不滅的你========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23157
#
# =======魔法水果籃 最終季========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23159
#
# =======奇巧計程車========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23161
#
# =======冰冰冰 冰淇淋君========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23163
#
# =======PUI PUI 天竺鼠車車========
# 最新連載 = 第1A集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23379
#
# =======關於我轉生變成史萊姆這檔事 第二季========
# 最新連載 = 第36.5集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23287
#
# day_of_week = 週三
# =======青梅竹馬絕對不會輸的戀愛喜劇========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23179
#
# day_of_week = 週四
# =======桃子男孩渡海而來========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23342
#
# =======緋紅結繫========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23273
#
# =======暮蟬悲鳴時 卒========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23344
#
# day_of_week = 週五
# =======轉生成蜘蛛又怎樣！========
# 最新連載 = 第24集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23109
#
# day_of_week = 週六
# =======瓦尼塔斯的手札========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23348
#
# =======叫我對大哥 (TV版)========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23349
#
# =======轉生成女性向遊戲只有毀滅 END 的壞人大小姐 X========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23350
#
# =======BLUE REFLECTION : 澪========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23111
#
# =======女朋友 and 女朋友========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23381
#
# =======壽司大相撲========
# 最新連載 = 第14集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23353
#
# =======勇者鬥惡龍 達伊的大冒險========
# 最新連載 = 第38集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23356
#
# =======我的英雄學院 第五季========
# 最新連載 = 第102集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23119
#
# =======入間同學入魔了 第二季========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23360
#
# =======我們的重製人生========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23375
#
# =======持續狩獵史萊姆三百年，不知不覺就練到 LV MAX========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23123
#
# =======卡片戰鬥!! 先導者 overdress========
# 最新連載 = 第12集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23125
#
# day_of_week = 週日
# =======Vivy -Fluorite Eye's Song-========
# 最新連載 = 第13.5集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23329
#
# =======魔法科高中的優等生========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23362
#
# =======不要欺負我，長瀞同學========
# 最新連載 = 第11集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23371
#
# =======86－不存在的戰區－========
# 最新連載 = 第11.5集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23330
#
# =======SHADOWS HOUSE-影宅-========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23133
#
# =======RE-MAIN========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23363
#
# =======現實主義勇者的王國重建記========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23364
#
# =======東京復仇者========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23365
#
# =======蓋特機器人 ARC========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23367
#
# =======死神少爺與黑女僕========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23376
#
# =======IDOLiSH7 - 偶像星願 - Third BEAT！========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23368
#
# =======偵探已經，死了。========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23369
#
# =======憂國的莫里亞蒂 第一季 後半========
# 最新連載 = 第24集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23138
#
# =======NOMAD MEGALOBOX 機甲拳擊 第二季========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23140
#
# {'週一': {'再見了，我的克拉默_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23142', '王者天下 第三季_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23145', '刮掉鬍子的我與撿到的女高中生_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23151'}, '週二': {'給不滅的你_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23157', '魔法水果籃 最終季_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23159', '奇巧計程車_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23161', '冰冰冰 冰淇淋君_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23163', 'PUI PUI 天竺鼠車車_第1A集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23379', '關於我轉生變成史萊姆這檔事 第二季_第36.5集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23287'}, '週三': {'青梅竹馬絕對不會輸的戀愛喜劇_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23179'}, '週四': {'桃子男孩渡海而來_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23342', '緋紅結繫_第2集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23273', '暮蟬悲鳴時 卒_第2集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23344'}, '週五': {'轉生成蜘蛛又怎樣！_第24集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23109'}, '週六': {'瓦尼塔斯的手札_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23348', '叫我對大哥 (TV版)_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23349', '轉生成女性向遊戲只有毀滅 END 的壞人大小姐 X_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23350', 'BLUE REFLECTION : 澪_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23111', '女朋友 and 女朋友_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23381', '壽司大相撲_第14集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23353', '勇者鬥惡龍 達伊的大冒險_第38集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23356', '我的英雄學院 第五季_第102集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23119', '入間同學入魔了 第二季_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23360', '我們的重製人生_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23375', '持續狩獵史萊姆三百年，不知不覺就練到 LV MAX_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23123', '卡片戰鬥!! 先導者 overdress_第12集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23125'}, '週日': {"Vivy -Fluorite Eye's Song-_第13.5集": 'https://ani.gamer.com.tw/animeVideo.php?sn=23329', '魔法科高中的優等生_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23362', '不要欺負我，長瀞同學_第11集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23371', '86－不存在的戰區－_第11.5集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23330', 'SHADOWS HOUSE-影宅-_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23133', 'RE-MAIN_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23363', '現實主義勇者的王國重建記_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23364', '東京復仇者_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23365', '蓋特機器人 ARC_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23367', '死神少爺與黑女僕_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23376', 'IDOLiSH7 - 偶像星願 - Third BEAT！_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23368', '偵探已經，死了。_第1集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23369', '憂國的莫里亞蒂 第一季 後半_第24集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23138', 'NOMAD MEGALOBOX 機甲拳擊 第二季_第13集': 'https://ani.gamer.com.tw/animeVideo.php?sn=23140'}}
