# %%
import pandas as pd

# %%
link = "https://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=466920&stname=%25E8%2587%25BA%25E5%258C%2597&datepicker=2021-07-08"
df = pd.read_html(link, encoding="utf-8")

# %%
print(df)
# Out:
# [                  0             1  \
# 0  日報表 (daily data)  測站:466920_臺北
#
#                                                    2   3                4   5  \
# 0  466930_竹子湖  466910_鞍部  466920_臺北  C0A980_社子  C... NaN  觀測時間:2021-07-08 NaN
#
#     6      7   8                    9
# 0 NaN  CSV下載 NaN  資料定義請詳見 ◎網頁說明Readme  ,    Unnamed: 0_level_0     Press            temperature    dew point      RH  \
#            觀測時間(hour) 測站氣壓(hPa) 海平面氣壓(hPa)       氣溫(℃)      露點溫度(℃) 相對溼度(%)
#               ObsTime   StnPres    SeaPres Temperature Td dew point      RH
# 0                   1    1008.8     1012.3        28.8         25.8      84
# 1                   2    1008.5     1012.0        28.5         25.5      84
# 2                   3    1008.4     1011.9        28.3         25.3      84
# 3                   4    1008.5     1012.0        28.3         24.9      82
# 4                   5    1008.7     1012.2        27.8         25.1      85
# ...

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#                   0             1  \
# 0  日報表 (daily data)  測站:466920_臺北
#
#                                                    2   3                4   5  \
# 0  466930_竹子湖  466910_鞍部  466920_臺北  C0A980_社子  C... NaN  觀測時間:2021-07-08 NaN
#
#     6      7   8                    9
# 0 NaN  CSV下載 NaN  資料定義請詳見 ◎網頁說明Readme

# %%
df[1]
# Out:
#    Unnamed: 0_level_0     Press            temperature    dew point      RH  \
#            觀測時間(hour) 測站氣壓(hPa) 海平面氣壓(hPa)       氣溫(℃)      露點溫度(℃) 相對溼度(%)
#               ObsTime   StnPres    SeaPres Temperature Td dew point      RH
# 0                   1    1008.8     1012.3        28.8         25.8      84
# 1                   2    1008.5     1012.0        28.5         25.5      84
# 2                   3    1008.4     1011.9        28.3         25.3      84
# 3                   4    1008.5     1012.0        28.3         24.9      82
# 4                   5    1008.7     1012.2        27.8         25.1      85
# 5                   6    1009.2     1012.7        27.9         25.0      84
# 6                   7    1009.5     1013.0        28.7         24.7      79
# 7                   8    1009.9     1013.4        30.0         25.1      75
# 8                   9    1009.8     1013.2        31.7         25.6      70
# ...

# %%
df = df[1]

# %%
df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',        '觀測時間(hour)',      'ObsTime'),
#             (             'Press',         '測站氣壓(hPa)',      'StnPres'),
#             (             'Press',        '海平面氣壓(hPa)',      'SeaPres'),
#             (       'temperature',             '氣溫(℃)',  'Temperature'),
#             (         'dew point',           '露點溫度(℃)', 'Td dew point'),
#             (                'RH',           '相對溼度(%)',           'RH'),
#             (             'WD/WS',           '風速(m/s)',           'WS'),
#             (             'WD/WS',     '風向(360degree)',           'WD'),
#             (             'WD/WS',         '最大陣風(m/s)',       'WSGust'),
#             (             'WD/WS', '最大陣風風向(360degree)',       'WDGust'),
#             (             'Precp',           '降水量(mm)',        'Precp'),
#             (             'Precp',           '降水時數(h)',    'PrecpHour'),
#             (          'SunShine',           '日照時數(h)',     'SunShine'),
# ...

# %%
df.columns = ["index", "觀測時間(hour)", "測站氣壓(hPa)", "海平面氣壓(hPa)", "氣溫(℃)", "露點溫度(℃)", \
              "相對溼度(%)", "風速(m/s)", "風向(360degree)", "最大陣風(m/s)"\
              '最大陣風風向(360degree)', '降水量(mm)', '降水時數(h)', '日照時數(h)',\
              '全天空日射量(MJ/㎡)', '能見度(km)', '紫外線指數',  '總雲量(0~10)'
             ]

# %%
df.columns
# Out:
# Index(['index', '觀測時間(hour)', '測站氣壓(hPa)', '海平面氣壓(hPa)', '氣溫(℃)', '露點溫度(℃)',
#        '相對溼度(%)', '風速(m/s)', '風向(360degree)', '最大陣風(m/s)最大陣風風向(360degree)',
#        '降水量(mm)', '降水時數(h)', '日照時數(h)', '全天空日射量(MJ/㎡)', '能見度(km)', '紫外線指數',
#        '總雲量(0~10)'],
#       dtype='object')

# %%
df.head()
# Out:
#    index  觀測時間(hour)  測站氣壓(hPa)  海平面氣壓(hPa)  氣溫(℃)  露點溫度(℃)  相對溼度(%)  風速(m/s)  \
# 0      1      1008.8     1012.3        28.8   25.8       84      1.6      150
# 1      2      1008.5     1012.0        28.5   25.5       84      1.0      190
# 2      3      1008.4     1011.9        28.3   25.3       84      0.8      170
# 3      4      1008.5     1012.0        28.3   24.9       82      0.9      170
# 4      5      1008.7     1012.2        27.8   25.1       85      1.5      180
#
#    風向(360degree)  最大陣風(m/s)最大陣風風向(360degree)  降水量(mm)  降水時數(h) 日照時數(h)  \
# 0            2.9                         140      0.0      0.0     ...
# 1            3.2                         180      0.0      0.0     ...
# 2            3.2                         170      0.0      0.0     ...
# 3            2.6                         170      0.0      0.0     ...
# 4            3.1                         160      0.0      0.0     ...
#
#    全天空日射量(MJ/㎡) 能見度(km)  紫外線指數 總雲量(0~10)
# ...

# %%
df["氣溫(℃)"]
# Out:
# 0     25.8
# 1     25.5
# 2     25.3
# 3     24.9
# 4     25.1
# 5     25.0
# 6     24.7
# 7     25.1
# 8     25.6
# 9     25.2
# 10    25.3
# 11    26.2
# 12    26.4
# 13    26.2
# 14    25.2
# 15    23.6
# 16    22.8
# 17    23.2
# 18    23.4
# 19    24.1
# 20    24.3
# 21    24.5
# 22    25.2
# 23    25.2
# Name: 氣溫(℃), dtype: float64
