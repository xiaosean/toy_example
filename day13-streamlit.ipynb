# %%
from pyquery import PyQuery as pq
from requests_html import HTMLSession
import pandas as pd
import streamlit as st
from PIL import Image

@st.cache(allow_output_mutation=True)
def ani_gamer_query():
    # 獲取請求對象 
    session = HTMLSession() 
    # 往巴哈姆特動畫瘋發送get請求 
    ani_gamer = session.get('https://ani.gamer.com.tw/') 

    page = pq(ani_gamer.text) 
    df_list = []
    for block in page.find(".anime-block"):
        anime_name = pq(block).find(".anime-name_for-marquee").text()
        anime_episode = pq(block).find(".anime-episode").text()
        href =  "https://ani.gamer.com.tw/" + pq(block).find(".anime-card-block").attr("href")
        img_link =  pq(block).find(".anime-blocker").find("img").attr("src")
        print(f"======={anime_name}========")
        print(f"最新連載 = {anime_episode}")
        print(f"連結 = {href}")
        print(f"img_link = {img_link}")
        df_list += [[anime_name, anime_episode, href, img_link]]
    df = pd.DataFrame(columns=["name", "eposide", "link", "image_link"], data=df_list)
    return df

def run():

    # ===============================
    # Get Anime dataframe
    # ===============================
    anime_df = ani_gamer_query()
    # ===============================
    # Construct demo site by streamlit
    # ===============================
    with st.sidebar:
        st.header("Ani gamer")
        with st.form(key="grid_reset"):
            n_cols = st.number_input("Number of columns", 2, 4, 2)
            st.form_submit_button(label="Get the anime list")
    
    # Create demo columns on website
#      # Load demo images
#     image1 = Image.open('YOUR IMAGE')
#     image2 = Image.open('YOUR IMAGE')
#     demo_left_column, demo_right_column = st.beta_columns(2)
#     demo_left_column.image(image1,  caption = "Demo 1 image")
#     demo_right_column.image(image2, caption = "Demo 2 image")

    
    st.title('Anime gamer - xiaosean')
    st.write(" ------ ")
    
    # Create dataframe by streamlit magic commands
#     anime_df
    st.dataframe(anime_df)  # Same as st.write(df)
    
    # Create grid
    n_anime = len(anime_df)
    n_rows = 1 + n_anime // n_cols
    rows = [st.beta_container() for _ in range(n_rows)]
    cols_per_row = [r.beta_columns(n_cols) for r in rows]

    start_time = time.time()
    for idx in range(n_anime):
        with rows[idx // n_cols]:
            # Generate with alpha and latent code attributes.
#             cols_per_row[image_index // n_cols][image_index % n_cols].image(result)
            name, eposide, link, image_link = df.iloc[idx]
            im = Image.open(requests.get(image_link, stream=True).raw)
            cols_per_row[idx // n_cols][idx % n_cols].image(im, caption=f"{name}_{eposide}_{link}")
    spend_time = time.time() - start_time
    print(f"Total cost time = {spend_time}, each image average cost {spend_time/n_photos}")

    
    
if __name__ == '__main__':
    run()
# Out:
# 2021-07-15 19:42:59.896
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/xiaosean/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in to_bytes(self, obj, context)
#     353             # Hash the input
# --> 354             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     355
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _to_bytes(self, obj, context)
#     616
# --> 617             if self._file_should_be_hashed(obj.__code__.co_filename):
#     618                 context = _get_context(obj)
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _file_should_be_hashed(self, filename)
#     395         return file_util.file_is_in_folder_glob(
# --> 396             filepath, self._get_main_script_directory()
#     397         ) or file_util.file_in_pythonpath(filepath)
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _get_main_script_directory()
#     700         # script path in ScriptRunner.
# --> 701         main_path = __main__.__file__
#     702         return os.path.dirname(main_path)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# <ipython-input-23-81fbaa5a29a0> in <module>
#      72
#      73 if __name__ == '__main__':
# ---> 74     run()
#
# <ipython-input-23-81fbaa5a29a0> in run()
#      26     # Get Anime dataframe
#      27     # ===============================
# ---> 28     anime_df = ani_gamer_query()
#      29     # ===============================
#      30     # Construct demo site by streamlit
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/caching.py in wrapped_func(*args, **kwargs)
#     571         if show_spinner:
#     572             with st.spinner(message):
# --> 573                 return get_or_create_cached_value()
#     574         else:
#     575             return get_or_create_cached_value()
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/caching.py in get_or_create_cached_value()
#     496                 # If we generated the key earlier we would only hash those
#     497                 # globals by name, and miss changes in their code or value.
# --> 498                 cache_key = _hash_func(func, hash_funcs)
#     499
#     500             # First, get the cache that's attached to this function.
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/caching.py in _hash_func(func, hash_funcs)
#     622     # because this step will be hashing any objects referenced in the function
#     623     # body.
# --> 624     update_hash(
#     625         func,
#     626         hasher=func_hasher,
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#      92
#      93     ch = _CodeHasher(hash_funcs)
# ---> 94     ch.update(hasher, val, context)
#      95
#      96
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in update(self, hasher, obj, context)
#     377     def update(self, hasher, obj, context=None):
#     378         """Update the provided hasher with the hash of an object."""
# --> 379         b = self.to_bytes(obj, context)
#     380         hasher.update(b)
#     381
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in to_bytes(self, obj, context)
#     366
#     367         except BaseException as e:
# --> 368             raise InternalHashError(e, obj)
#     369
#     370         finally:
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in to_bytes(self, obj, context)
#     352         try:
#     353             # Hash the input
# --> 354             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     355
#     356             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _to_bytes(self, obj, context)
#     615             h = hashlib.new("md5")
#     616
# --> 617             if self._file_should_be_hashed(obj.__code__.co_filename):
#     618                 context = _get_context(obj)
#     619                 if obj.__defaults__:
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _file_should_be_hashed(self, filename)
#     394             return False
#     395         return file_util.file_is_in_folder_glob(
# --> 396             filepath, self._get_main_script_directory()
#     397         ) or file_util.file_in_pythonpath(filepath)
#     398
#
# ~/anaconda3/lib/python3.8/site-packages/streamlit/hashing.py in _get_main_script_directory()
#     699         # This works because we set __main__.__file__ to the report
#     700         # script path in ScriptRunner.
# --> 701         main_path = __main__.__file__
#     702         return os.path.dirname(main_path)
#     703
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `ani_gamer_query()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function ani_gamer_query at 0x7f8d216474c0>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/en/stable/caching.html#the-hash-funcs-parameter)
# for more details.

# %%
# !streamlit run demo.py --server.port 8051

# %%
def ani_gamer_query():
    # 獲取請求對象 
    session = HTMLSession() 
    # 往巴哈姆特動畫瘋發送get請求 
    ani_gamer = session.get('https://ani.gamer.com.tw/') 
    

    df_list = []
    for block in page.find(".anime-block"):
        anime_name = pq(block).find(".anime-name_for-marquee").text()
        href =  "https://ani.gamer.com.tw/" + pq(block).find(".anime-card-block").attr("href")
        anime_episode = pq(block).find(".anime-episode").text()
        img_link =  pq(block).find("lazyloaded").text()
        print(f"======={anime_name}========")
        print(f"最新連載 = {anime_episode}")
        print(f"連結 = {href}")
        print(f"img_link = {img_link}")
    df = pd.DataFrame(columns=["name", "eposide", "link", "image_link"], data=df_list)

# %%
def ani_gamer_query():
    # 獲取請求對象 
    session = HTMLSession() 
    # 往巴哈姆特動畫瘋發送get請求 
    ani_gamer = session.get('https://ani.gamer.com.tw/') 

    page = pq(ani_gamer.text) 
    df_list = []
    for block in page.find(".anime-block"):
        anime_name = pq(block).find(".anime-name_for-marquee").text()
        anime_episode = pq(block).find(".anime-episode").text()
        href =  "https://ani.gamer.com.tw/" + pq(block).find(".anime-card-block").attr("href")
        img_link =  pq(block).find(".anime-blocker").find("img").attr("src")
        print(f"======={anime_name}========")
        print(f"最新連載 = {anime_episode}")
        print(f"連結 = {href}")
        print(f"img_link = {img_link}")
        df_list += [[anime_name, anime_episode, href, img_link]]
    df = pd.DataFrame(columns=["name", "eposide", "link", "image_link"], data=df_list)
# Out:
# =======女神宿舍的管理員。========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23341
# img_link = https://p2.bahamut.com.tw/B/2KU/70/d442caa314656a6ab1e6e8686a1d0925.JPG
# =======女神宿舍的管理員。========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23340
# img_link = https://p2.bahamut.com.tw/B/2KU/69/5815fc8d37c68aa2a92ff439c71d0915.JPG
# =======月光下的異世界之旅========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23534
# img_link = https://p2.bahamut.com.tw/B/2KU/21/0f65e260689949611cba95d1571cztt5.JPG
# =======開掛藥師的異世界悠閒生活========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23532
# img_link = https://p2.bahamut.com.tw/B/2KU/12/c91a3287b331b029a2c1a2eb4e1d0a85.JPG
# =======叫我對大哥 (WEB版)========
# 最新連載 = 第4集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23500
# img_link = https://p2.bahamut.com.tw/B/2KU/22/c2e8a4fda12380616d49f5e8331cztu5.JPG
# =======關於我轉生變成史萊姆這檔事 第二季========
# 最新連載 = 第38集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23497
# img_link = https://p2.bahamut.com.tw/B/2KU/19/bed52984c9d09ac5cf77b66b311czwj5.JPG
# =======PUI PUI 天竺鼠車車========
# 最新連載 = 第2A集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23496
# img_link = https://p2.bahamut.com.tw/B/2KU/85/98baf9dfe8baa4a69b0c45d9361czex5.JPG
# =======急戰 5 秒殊死鬥========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23337
# img_link = https://p2.bahamut.com.tw/B/2KU/36/a64b51754e6ad7b0c8e18dc5fe1czdk5.JPG
# =======給不滅的你========
# 最新連載 = 第13集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23334
# img_link = https://p2.bahamut.com.tw/B/2KU/73/d1c81a59d69a2c5e4056dc1c2f1czel5.JPG
# =======Love Live! Superstar!!========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23333
# img_link = https://p2.bahamut.com.tw/B/2KU/74/ffbedf3290789d73050d39032e1czhe5.JPG
# =======闇芝居 第九季========
# 最新連載 = 第1集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23370
# img_link = https://p2.bahamut.com.tw/B/2KU/26/d379d25317aff1d7f2461e82b61cz265.JPG
# =======IDOLiSH7 - 偶像星願 - Third BEAT！========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=23490
# img_link = https://p2.bahamut.com.tw/B/2KU/23/c445de9deb9fcb3a6368c572961cz235.JPG
# =======偵探已經，死了。========
# 最新連載 = 第2集
# 連結 = https://ani.gamer.com.tw/animeVideo.php?sn=