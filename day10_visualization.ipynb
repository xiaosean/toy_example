# %%
import pandas as pd

# %% [markdown]
# # Load csv file

# %%
df = pd.read_csv("./netflix-rotten-tomatoes-metacritic-imdb.csv")

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %% [markdown]
# # 繪製圖表

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
sns.distplot(df["Hidden Gem Score"], norm_hist=True,kde=False)
# Out:
# /Users/xiaosean/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
df["Runtime"].value_counts()
# Out:
# 1-2 hour        9121
# < 30 minutes    3996
# > 2 hrs         2028
# 30-60 mins       334
# Name: Runtime, dtype: int64

# %%
df.groupby("Runtime").count()
# Out:
#               Title  Genre  Tags  Languages  Series or Movie  \
# Runtime
# 1-2 hour       9121   8177  9089       8108             9121
# 30-60 mins      334    245   333        234              334
# < 30 minutes   3996   3420  3968       3280             3996
# > 2 hrs        2028   1927  2022       1922             2028
#
#               Hidden Gem Score  Country Availability  Director  Writer  \
# Runtime
# 1-2 hour                  7982                  9112      8025    7652
# 30-60 mins                 236                   333       218     162
# < 30 minutes              3252                  3991       626    1488
# > 2 hrs                   1908                  2024      1903    1848
#
#               Actors  ...  Netflix Release Date  Production House  \
# Runtime               ...
# 1-2 hour        8096  ...                  9121              3911
# 30-60 mins       231  ...                   334                33
# ...

# %%
type(df.groupby("Runtime").count())
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#        Title  Genre   Tags  Languages  Series or Movie  Hidden Gem Score  \
# 0      False  False  False      False            False             False
# 1      False  False  False      False            False             False
# 2      False  False  False      False            False             False
# 3      False  False  False      False            False             False
# 4      False  False  False      False            False             False
# ...      ...    ...    ...        ...              ...               ...
# 15475  False   True  False       True            False              True
# 15476  False   True  False       True            False              True
# 15477  False  False  False      False            False             False
# 15478  False  False  False      False            False             False
# 15479  False  False  False      False            False             False
#
#        Country Availability  Runtime  Director  Writer  ...  \
# ...

# %%
df.groupby("Runtime").count()

# %%
df["Runtime"].value_counts().plot.pie(autopct="%.1f%%");

# %%
df[df["IMDb Score"] >= 8]
# Out:
#                                        Title  \
# 15                                     Joker
# 17                          Harrys Daughters
# 27             Comrades: Almost a Love Story
# 33           When a Woman Ascends the Stairs
# 34                                  Yearning
# ...                                      ...
# 15409                         House of Cards
# 15429  The Lord of the Rings: The Two Towers
# 15444                 Hunter X Hunter (2011)
# 15451                          Stargate SG-1
# 15454                         Inazuma Eleven
#
#                                                    Genre  \
# 15                                Crime, Drama, Thriller
# 17                    Adventure, Drama, Fantasy, Mystery
# 27                                        Drama, Romance
# 33                                                 Drama
# 34                                                 Drama
# ...                                                  ...
# ...

# %%
df_higher = df[df["IMDb Score"] >= 8]

# %%
df_higher["Series or Movie"].value_counts()
# Out:
# Series    690
# Movie     482
# Name: Series or Movie, dtype: int64

# %%
df_higher["Series or Movie"].value_counts().plot.pie(autopct="%.1f%%");

# %%
# import library
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
tags = df_higher["Tags"]

# %%
tw = df_higher["Tags"]

# %%
tw
# Out:
# 15       Dark Comedies,Crime Comedies,Dramas,Comedies,C...
# 17                                   Dramas,Swedish Movies
# 27       Romantic Dramas,Chinese Movies,Dramas,Romantic...
# 33       Social Issue Dramas,Dramas,Japanese Movies,Cla...
# 34       Romantic Dramas,Dramas,Romantic Movies,Japanes...
#                                ...
# 15409    US TV Programmes,TV Dramas,TV Programmes,Polit...
# 15429    Sci-Fi & Fantasy,Action Sci-Fi & Fantasy,Fanta...
# 15444    Anime,Anime Fantasies,TV Programmes,Anime Seri...
# 15451    Cult TV Programmes,TV Action & Adventure,US TV...
# 15454    Anime,Kids TV,TV Programmes,Anime Series,Japan...
# Name: Tags, Length: 1172, dtype: object

# %%
taglist= df["Tags"].tolist()
taglist
# Out:
# ['Comedy Programmes,Romantic TV Comedies,Horror Programmes,Thai TV Programmes',
#  'Dramas,Comedies,Films Based on Books,British',
#  'Thrillers',
#  'TV Dramas,Romantic TV Dramas,Dutch TV Shows',
#  'Social Issue Dramas,Teen Movies,Dramas,Comedies,Movies Based on Books',
#  'Romantic Comedies,Comedies,Romantic Films,Thai Comedies,Thai Films',
#  'TV Dramas,Polish TV Shows,Social Issue TV Dramas',
#  'TV Dramas,Crime TV Dramas,Polish TV Shows',
#  'Social Issue Dramas,Dramas,Movies Based on Books,Period Pieces,Swedish Movies',
#  'Sports Movies,Sports Comedies,Comedies,Swedish Movies',
#  'Children & Family Movies,Comedies,Movies Based on Books,Family Features,Family Comedies,Swedish Movies',
#  'Thriller Movies,Movies Based on Books,Supernatural Thrillers,Swedish Movies',
#  'Social Issue Dramas,Dramas,Movies Based on Books,Period Pieces,Classic Movies,Swedish Movies',
#  'Romantic Dramas,Romantic Comedies,Dramas,Comedies,Romantic Movies,Swedish Movies',
#  'Dramas,Swedish Movies',
# ...

# %%
tag_str = ""
for tag in tw:
    tag_str += str(tag)
print(tag_str)
# Out:
# Dark Comedies,Crime Comedies,Dramas,Comedies,Crime Dramas,Swedish MoviesDramas,Swedish MoviesRomantic Dramas,Chinese Movies,Dramas,Romantic Movies,Hong Kong Movies,Romantic FavoritesSocial Issue Dramas,Dramas,Japanese Movies,Classic MoviesRomantic Dramas,Dramas,Romantic Movies,Japanese Movies,Classic MoviesSocial Issue Dramas,Dramas,LGBTQ Movies,Independent MoviesTV Dramas,Political TV Shows,BritishTV Dramas,Italian TV ShowsTV Comedies,TV Dramas,US TV ShowsKorean Movies,DramasKorean Movies,DramasTeen Movies,Romantic Dramas,Dramas,Romantic Movies,Movies Based on Books,Indonesian MoviesTV Dramas,Period Pieces,Political TV Shows,Social Issue TV DramasDrama Anime,Anime Series,Teen TV Shows,Japanese TV Shows,Romance Anime,School Anime,Family Watch Together TV,TV Shows Based on MangaTV Comedies,TV Dramas,Japanese TV SeriesPolitical Documentaries,Romanian Movies,DocumentariesTV Dramas,US TV Shows,TV Shows Based on Books,Social Issue TV DramasComedies,Swedish MoviesComedies,Swedish MoviesTV 
# ...

# %%
"".join(tw)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-fdd968f180c7> in <module>
# ----> 1 "".join(tw)
#
# TypeError: sequence item 284: expected str instance, float found

# %%
list(df_higher["Tags"])
# Out:
# ['Dark Comedies,Crime Comedies,Dramas,Comedies,Crime Dramas,Swedish Movies',
#  'Dramas,Swedish Movies',
#  'Romantic Dramas,Chinese Movies,Dramas,Romantic Movies,Hong Kong Movies,Romantic Favorites',
#  'Social Issue Dramas,Dramas,Japanese Movies,Classic Movies',
#  'Romantic Dramas,Dramas,Romantic Movies,Japanese Movies,Classic Movies',
#  'Social Issue Dramas,Dramas,LGBTQ Movies,Independent Movies',
#  'TV Dramas,Political TV Shows,British',
#  'TV Dramas,Italian TV Shows',
#  'TV Comedies,TV Dramas,US TV Shows',
#  'Korean Movies,Dramas',
#  'Korean Movies,Dramas',
#  'Teen Movies,Romantic Dramas,Dramas,Romantic Movies,Movies Based on Books,Indonesian Movies',
#  'TV Dramas,Period Pieces,Political TV Shows,Social Issue TV Dramas',
#  'Drama Anime,Anime Series,Teen TV Shows,Japanese TV Shows,Romance Anime,School Anime,Family Watch Together TV,TV Shows Based on Manga',
#  'TV Comedies,TV Dramas,Japanese TV Series',
#  'Political Documentaries,Romanian Movies,Documentaries',
# ...

# %%
words = []
for tag in tags:
    words += str(tag).replace(" ", "_").split(",")
# words = " ".join(words)

# %%
words
# Out:
# ['Dark_Comedies',
#  'Crime_Comedies',
#  'Dramas',
#  'Comedies',
#  'Crime_Dramas',
#  'Swedish_Movies',
#  'Dramas',
#  'Swedish_Movies',
#  'Romantic_Dramas',
#  'Chinese_Movies',
#  'Dramas',
#  'Romantic_Movies',
#  'Hong_Kong_Movies',
#  'Romantic_Favorites',
#  'Social_Issue_Dramas',
#  'Dramas',
#  'Japanese_Movies',
#  'Classic_Movies',
#  'Romantic_Dramas',
#  'Dramas',
#  'Romantic_Movies',
#  'Japanese_Movies',
#  'Classic_Movies',
#  'Social_Issue_Dramas',
#  'Dramas',
#  'LGBTQ_Movies',
#  'Independent_Movies',
#  'TV_Dramas',
#  'Political_TV_Shows',
#  'British',
#  'TV_Dramas',
#  'Italian_TV_Shows',
#  'TV_Comedies',
#  'TV_Dramas',
#  'US_TV_Shows',
#  'Korean_Movies',
#  'Dramas',
#  'Korean_Movies',
#  'Dramas',
#  'Teen_Movies',
#  'Romantic_Dramas',
#  'Dramas',
#  'Romantic_Movies',
#  'Movies_Based_on_Books',
#  'Indonesian_Movies',
#  'TV_Dramas',
#  'Period_Pieces',
#  'Political_TV_Shows',
#  'Social_Issue_TV_Dramas',
#  'Drama_Anime',
#  'Anime_Series',
# ...

# %%
word_counter = Counter(words)

# %%
word_counter.most_common(40)
# Out:
# [('TV_Programmes', 317),
#  ('TV_Dramas', 242),
#  ('Dramas', 241),
#  ('TV_Comedies', 167),
#  ('Anime_Series', 116),
#  ('Comedies', 115),
#  ('Documentaries', 108),
#  ('Action_&_Adventure', 98),
#  ('TV_Shows', 96),
#  ('Anime', 89),
#  ('International_Dramas', 81),
#  ('US_TV_Programmes', 78),
#  ('International_Movies', 77),
#  ('US_Movies', 70),
#  ('Romantic_TV_Dramas', 69),
#  ('US_TV_Shows', 68),
#  ('Crime_TV_Dramas', 67),
#  ('TV_Thrillers', 62),
#  ('Korean_TV_Shows', 57),
#  ('Crime_Dramas', 56),
#  ('Sci-Fi_&_Fantasy', 56),
#  ('Japanese_TV_Shows', 55),
#  ('Sci-Fi_&_Fantasy_Anime', 54),
#  ('TV_Shows_Based_on_Books', 53),
#  ('TV_Action_&_Adventure', 53),
#  ('Movies_Based_on_Books', 52),
#  ('Thrillers', 52),
#  ('Kids_TV', 52),
#  ('British_TV_Programmes', 51),
#  ('Docuseries', 50),
#  ('Classic_Films', 49),
#  ('Period_Pieces', 48),
#  ('TV_Cartoons', 48),
#  ('Sitcoms', 48),
#  ('Award-winning_Movies', 47),
#  ('Social_Issue_Dramas', 44),
# ...

# %%
words = []
for tag in tags:
    words += str(tag).replace("&", "").replace(" ", "_").split(",")
#     words += str(tag).split(",")
words = " ".join(words)

# %%
words
# Out:
# 'Dark_Comedies Crime_Comedies Dramas Comedies Crime_Dramas Swedish_Movies Dramas Swedish_Movies Romantic_Dramas Chinese_Movies Dramas Romantic_Movies Hong_Kong_Movies Romantic_Favorites Social_Issue_Dramas Dramas Japanese_Movies Classic_Movies Romantic_Dramas Dramas Romantic_Movies Japanese_Movies Classic_Movies Social_Issue_Dramas Dramas LGBTQ_Movies Independent_Movies TV_Dramas Political_TV_Shows British TV_Dramas Italian_TV_Shows TV_Comedies TV_Dramas US_TV_Shows Korean_Movies Dramas Korean_Movies Dramas Teen_Movies Romantic_Dramas Dramas Romantic_Movies Movies_Based_on_Books Indonesian_Movies TV_Dramas Period_Pieces Political_TV_Shows Social_Issue_TV_Dramas Drama_Anime Anime_Series Teen_TV_Shows Japanese_TV_Shows Romance_Anime School_Anime Family_Watch_Together_TV TV_Shows_Based_on_Manga TV_Comedies TV_Dramas Japanese_TV_Series Political_Documentaries Romanian_Movies Documentaries TV_Dramas US_TV_Shows TV_Shows_Based_on_Books Social_Issue_TV_Dramas Comedies Swedish_Movies Comedie
# ...

# %%
# create wordcloud
wordcloud = WordCloud(max_font_size=40, collocations=False).generate(tag_str)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
